# %% [markdown]
# ## **Mounting**

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Import Dataset from drive

# %%
import os

train_dir = "/content/gdrive/MyDrive/Colab Notebooks/Matkul Kecerdasan Buatan /tubes2/daun herbal/train"
val_dir = "/content/gdrive/MyDrive/Colab Notebooks/Matkul Kecerdasan Buatan /tubes2/daun herbal/val"

belimbing_train_path = train_dir + '/Belimbing Wuluh'
jambubiji_train_path = train_dir + '/Jambu biji'
jeruk_train_path = train_dir + '/Jeruk'
kemangi_train_path = train_dir + '/Kemangi'
lidahbuaya_train_path = train_dir + '/Lidah buaya'
nangka_train_path = train_dir + '/Nangka'
pandan_train_path = train_dir + '/Pandan'
pepaya_train_path = train_dir + '/Pepaya'
seledri_train_path = train_dir + '/Seledri'
sirih_train_path = train_dir + '/Sirih'
belimbing_val_path = val_dir + '/Belimbing Wuluh'
jambubiji_val_path = val_dir + '/Jambu biji'
jeruk_val_path = val_dir + '/Jeruk'
kemangi_val_path = val_dir + '/Kemangi'
lidahbuaya_val_path = val_dir + '/Lidah buaya'
nangka_val_path = val_dir + '/Nangka'
pandan_val_path = val_dir + '/Pandan'
pepaya_val_path = val_dir + '/Pepaya'
seledri_val_path = val_dir + '/Seledri'
sirih_val_path = val_dir + '/Sirih'

belimbing_len_train = len(os.listdir(belimbing_train_path))
jambubiji_len_train = len(os.listdir(jambubiji_train_path))
jeruk_len_train = len(os.listdir(jeruk_train_path))
kemangi_len_train = len(os.listdir(kemangi_train_path))
lidahbuaya_len_train = len(os.listdir(lidahbuaya_train_path))
nangka_len_train = len(os.listdir(nangka_train_path))
pandan_len_train = len(os.listdir(pandan_train_path))
pepaya_len_train = len(os.listdir(pepaya_train_path))
seledri_len_train = len(os.listdir(seledri_train_path))
sirih_len_train = len(os.listdir(sirih_train_path))
belimbing_len_val = len(os.listdir(belimbing_val_path))
jambubiji_len_val = len(os.listdir(jambubiji_val_path))
jeruk_len_val = len(os.listdir(jeruk_val_path))
kemangi_len_val = len(os.listdir(kemangi_val_path))
lidahbuaya_len_val = len(os.listdir(lidahbuaya_val_path))
nangka_len_val = len(os.listdir(nangka_val_path))
pandan_len_val = len(os.listdir(pandan_val_path))
pepaya_len_val = len(os.listdir(pepaya_val_path))
seledri_len_val = len(os.listdir(seledri_val_path))
sirih_len_val = len(os.listdir(sirih_val_path))


print("jumlah dataset Training : ", belimbing_len_train + jambubiji_len_train + jeruk_len_train + kemangi_len_train + lidahbuaya_len_train + nangka_len_train + pandan_len_train + pepaya_len_train + seledri_len_train + sirih_len_train)
print("jumlah dataset validasi : ", belimbing_len_val + jambubiji_len_val + jeruk_len_val + kemangi_len_val + lidahbuaya_len_val + nangka_len_val + pandan_len_val + pepaya_len_val + seledri_len_val + sirih_len_val)
print("\n\n")
print("jumlah train kelas Belimbing wuluh : ", belimbing_len_train)
print("jumlah train kelas Jambu biji : ", jambubiji_len_train)
print("jumlah train kelas Jeruk : ", jeruk_len_train)
print("jumlah train kelas Kemangi : ", kemangi_len_train)
print("jumlah train kelas Lidah buaya : ", lidahbuaya_len_train)
print("jumlah train kelas Nangka : ", nangka_len_train)
print("jumlah train kelas Pandan : ", pandan_len_train)
print("jumlah train kelas Pepaya : ", pepaya_len_train)
print("jumlah train kelas Seledri : ", seledri_len_train)
print("jumlah train kelas sirih : ", sirih_len_train)
print("jumlah validasi kelas Belimbing wuluh : ", belimbing_len_val)
print("jumlah validasi kelas Jambu biji : ", jambubiji_len_val)
print("jumlah validasi kelas Jeruk : ", jeruk_len_val)
print("jumlah validasi kelas Kemangi : ", kemangi_len_val)
print("jumlah validasi kelas Lidah buaya : ", lidahbuaya_len_val)
print("jumlah validasi kelas Nangka : ", nangka_len_val)
print("jumlah validasi kelas Pandan : ", pandan_len_val)
print("jumlah validasi kelas Pepaya : ", pepaya_len_val)
print("jumlah validasi kelas Seledri : ", seledri_len_val)
print("jumlah validasi kelas Sirih : ", sirih_len_val)
# Out:
# jumlah dataset Training :  2590
# jumlah dataset validasi :  870
#
#
#
# jumlah train kelas Belimbing wuluh :  259
# jumlah train kelas Jambu biji :  259
# jumlah train kelas Jeruk :  259
# jumlah train kelas Kemangi :  259
# jumlah train kelas Lidah buaya :  259
# jumlah train kelas Nangka :  259
# jumlah train kelas Pandan :  259
# jumlah train kelas Pepaya :  259
# jumlah train kelas Seledri :  259
# jumlah train kelas sirih :  259
# jumlah validasi kelas Belimbing wuluh :  87
# jumlah validasi kelas Jambu biji :  87
# jumlah validasi kelas Jeruk :  87
# jumlah validasi kelas Kemangi :  87
# jumlah validasi kelas Lidah buaya :  87
# jumlah validasi kelas Nangka :  87
# jumlah validasi kelas Pandan :  87
# jumlah validasi kelas Pepaya :  87
# jumlah validasi kelas Seledri :  87
# jumlah validasi kelas Sirih :  87

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=50,
      width_shift_range=0.15,
      height_shift_range=0.15,
      shear_range=0.15,
      zoom_range=0.15,
      horizontal_flip=True,
      fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(300, 300),
        batch_size=25,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(300, 300),
        batch_size=25,
        class_mode='categorical')
# Out:
# Found 2590 images belonging to 10 classes.
# Found 870 images belonging to 10 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, AveragePooling2D, Flatten, GlobalAveragePooling2D, Dropout, MaxPooling2D
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
callbacks = EarlyStopping(monitor='val_loss', patience=15, verbose=1, mode='auto')        
directory_to_save_best_model_file = '/content/gdrive/MyDrive/Colab Notebooks/Matkul Kecerdasan Buatan/tubes2/callback.h5'
best_model = ModelCheckpoint(directory_to_save_best_model_file, monitor='val_accuracy', verbose = 1, save_best_only = True)

# %%
model = Sequential()

model.add(InputLayer(input_shape=[300,300,3]))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.01))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 298, 298, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 149, 149, 32)     0
#  )
#
#  dropout (Dropout)           (None, 149, 149, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 73, 73, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 73, 73, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 35, 35, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 35, 35, 128)       0
#
#  flatten (Flatten)           (None, 156800)            0
#
#  dense (Dense)               (None, 128)               20070528
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 20,165,066
# Trainable params: 20,165,066
# ...

# %%
# Compile model
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(lr=0.001), 
              loss='categorical_crossentropy', 
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=104,  # 2590 images = 25 batch_size * steps
      epochs=50,
      validation_data=validation_generator,
      validation_steps=35,  #  870 images = 25 batch_size * steps
      callbacks = [callbacks, best_model])
# Out:
# Epoch 1/50
# ...
# 104/104 [==============================] - 1376s 13s/step - loss: 3.9238 - acc: 0.0981 - val_loss: 2.3026 - val_acc: 0.1000
# Epoch 2/50
# ...
# 104/104 [==============================] - 174s 2s/step - loss: 2.3028 - acc: 0.0950 - val_loss: 2.3017 - val_acc: 0.1586
# Epoch 3/50
# ...
# 104/104 [==============================] - 174s 2s/step - loss: 2.2418 - acc: 0.1514 - val_loss: 2.0759 - val_acc: 0.2276
# Epoch 4/50
# ...
# 104/104 [==============================] - 174s 2s/step - loss: 1.9933 - acc: 0.2641 - val_loss: 1.8818 - val_acc: 0.2805
# Epoch 5/50
# ...
# 104/104 [==============================] - 174s 2s/step - loss: 1.7145 - acc: 0.3799 - val_loss: 1.7467 - val_acc: 0.3069
# Epoch 6/50
# ...
# 104/104 [==============================] - 174s 2s/step - loss: 1.5299 - acc: 0.4463 - val_loss: 1.6474 - val_acc: 0.3414
# Epoch 7/50
# ...
# 104/104 [==============================] - 173s 2s/step - loss: 1.4216 - acc: 0.4676 - val_loss: 1.8382 - val_acc: 0.3333
# Epoch 8/50
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np 
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, recall_score, accuracy_score
from sklearn.metrics import precision_score, confusion_matrix, classification_report
from sklearn import metrics

import seaborn as sns
sns.set(style='whitegrid')

# %%
from keras.models import load_model
model_path = '/content/gdrive/MyDrive/Colab Notebooks/Matkul Kecerdasan Buatan/tubes2/callback.h5'
model = load_model(model_path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-551808cf4f11> in <module>()
#       1 from keras.models import load_model
#       2 model_path = '/content/gdrive/MyDrive/Colab Notebooks/Matkul Kecerdasan Buatan/tubes2/callback.h5'
# ----> 3 model = load_model(model_path)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     207         if isinstance(filepath, str):
#     208           if not tf.io.gfile.exists(filepath):
# ...

# %%
def my_metrics(y_true, y_pred):
    accuracy=accuracy_score(y_true, y_pred)
    precision=precision_score(y_true, y_pred,average='weighted')
    f1Score=f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1Score))
    cm=confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1Score

height=200; width=200
batch_size=25

test_datagen = ImageDataGenerator(rescale=1./255)

TESTING_DIR = '/content/gdrive/MyDrive/Colab Notebooks/Matkul Kecerdasan Buatan /tubes2/daun herbal/test'

test_generator = test_datagen.flow_from_directory(TESTING_DIR,
                                                  batch_size=batch_size,                                                             
                                                  target_size=(height, width),
                                                  class_mode= None,
                                                  shuffle=False
                                                  )

predictions = model.predict_generator(generator=test_generator)
yPredictions = predictions > 0.5
true_classes = test_generator.classes
class_names = test_generator.class_indices
Cmatrix_test = confusion_matrix(true_classes, yPredictions)

testAcc,testPrec, testFScore = my_metrics(true_classes, yPredictions)

plt.figure(figsize=(20,20))
ax= plt.subplot()
data = np.asarray(Cmatrix_test).reshape(2,2)
sns.heatmap(data,annot=True, fmt='',ax=ax, cmap=plt.cm.Reds)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_names)   
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Test',fontsize=14)
plt.show()
# Out:
# Found 31 images belonging to 10 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-20-8a22588cebd5> in <module>()
#      24                                                   )
#      25
# ---> 26 predictions = model.predict_generator(generator=test_generator)
#      27 yPredictions = predictions > 0.5
#      28 true_classes = test_generator.classes
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    2088         use_multiprocessing=use_multiprocessing,
#    2089         verbose=verbose,
# ...
